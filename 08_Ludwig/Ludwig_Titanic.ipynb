# %% [markdown]
# **AutoML OSS入門（8）**
# # データ型ベースのディープラーニング AutoML OSS「Ludwig」
#
# 本ノートブックの紹介記事と併せてご覧ください。
# - [＠IT連載 AutoML OSS入門（8）- 第8回「データ型ベースのディープラーニングAutoML OSS「Ludwig」」](https://atmarkit.itmedia.co.jp/ait/articles/2112/21/news003.html)
#
# また、ノートブックの扱い方やタイタニックの生存予測データについては、連載記事の第1回も参照してください。
# - [＠IT連載 AutoML OSS入門（1）- 第1回「機械学習モデル構築作業の煩雑さを解消する「AutoML」とは――歴史、動向、利用のメリットを整理する」](https://www.atmarkit.co.jp/ait/articles/2107/02/news006.html)

# %% [markdown]
# ## タイタニックデータでAutoML
# タイタニックの生存予測データを使って、Ludwigを紹介していきます。

# %% [markdown]
# ### セットアップ
# Ludwigをインストールします。データの読み込みに使うライブラリであるPetastormも併せてインストールしておきます。

# %%
# Ludwigのインストール
# !pip install ludwig

# Petastormのインストール
# !pip install petastorm
# Out:
# Collecting ludwig
#   Downloading ludwig-0.4.tar.gz (342 kB)
#      |████████████████████████████████| 342 kB 18.0 MB/s
# Requirement already satisfied: Cython>=0.25 in /usr/local/lib/python3.7/dist-packages (from ludwig) (0.29.24)
# Requirement already satisfied: h5py!=3.0.0,>=2.6 in /usr/local/lib/python3.7/dist-packages (from ludwig) (3.1.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from ludwig) (1.19.5)
# Collecting pandas<1.1.5,>=0.25
#   Downloading pandas-1.1.4-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 35.3 MB/s
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from ludwig) (1.4.1)
# Requirement already satisfied: tabulate>=0.7 in /usr/local/lib/python3.7/dist-packages (from ludwig) (0.8.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from ludwig) (1.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from ludwig) (4.62.3)
# Requirement already satisfied: tensorflow>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from ludwig) (2.7.0)
# Collecting tensorflow-addons>=0.13.0
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 64.2 MB/s
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.7/dist-packages (from ludwig) (3.13)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from ludwig) (0.12.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from ludwig) (1.5.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ludwig) (2.23.0)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from ludwig) (3.4.4)
# Collecting fsspec
#   Downloading fsspec-2021.11.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 57.1 MB/s
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.6-py3-none-any.whl (25 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ludwig) (2.6.0)
# Requirement already satisfied: xlwt in /usr/local/lib/python3.7/dist-packages (from ludwig) (1.3.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from ludwig) (1.1.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (from ludwig) (2.5.9)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from ludwig) (3.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from ludwig) (4.2.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py!=3.0.0,>=2.6->ludwig) (1.5.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<1.1.5,>=0.25->ludwig) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.1.5,>=0.25->ludwig) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<1.1.5,>=0.25->ludwig) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (12.0.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (0.37.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (2.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (1.6.3)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (3.10.0.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (3.17.3)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (2.7.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (1.42.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (1.13.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (0.22.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.3.1->ludwig) (3.1.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons>=0.13.0->ludwig) (2.7.1)
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.14.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.9 MB/s
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->ludwig) (5.0.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl->ludwig) (1.1.0)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl->ludwig) (1.4.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->ludwig) (1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->ludwig) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->ludwig) (1.1.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.7/dist-packages (from tables->ludwig) (2.7.3)
# Building wheels for collected packages: ludwig
#   Building wheel for ludwig (setup.py) ... done
#   Created wheel for ludwig: filename=ludwig-0.4-py3-none-any.whl size=423616 sha256=bfbabb412a247cc9e0373397f9edcc3f19b29da3b1896b87416e1bc5736016bb
#   Stored in directory: /root/.cache/pip/wheels/26/3f/00/ccf96056909f13add23251dd78ddfab5e1621125d249947bad
# Successfully built ludwig
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, marshmallow-enum, tensorflow-addons, pandas, fsspec, dataclasses-json, ludwig
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# Successfully installed dataclasses-json-0.5.6 fsspec-2021.11.0 ludwig-0.4 marshmallow-3.14.1 marshmallow-enum-1.5.1 mypy-extensions-0.4.3 pandas-1.1.4 tensorflow-addons-0.15.0 typing-inspect-0.7.1
# Collecting petastorm
#   Downloading petastorm-0.11.3-py2.py3-none-any.whl (283 kB)
#      |████████████████████████████████| 283 kB 28.9 MB/s
# Requirement already satisfied: packaging>=15.0 in /usr/local/lib/python3.7/dist-packages (from petastorm) (21.3)
# Requirement already satisfied: dill>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from petastorm) (0.3.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from petastorm) (1.19.5)
# Collecting diskcache>=3.0.0
#   Downloading diskcache-5.2.1-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.7 MB/s
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from petastorm) (1.15.0)
# Collecting pyspark>=2.1.0
#   Downloading pyspark-3.2.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 40 kB/s
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from petastorm) (2021.11.0)
# Requirement already satisfied: pandas>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from petastorm) (1.1.4)
# Requirement already satisfied: pyzmq>=14.0.0 in /usr/local/lib/python3.7/dist-packages (from petastorm) (22.3.0)
# Requirement already satisfied: psutil>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from petastorm) (5.4.8)
# Requirement already satisfied: pyarrow>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from petastorm) (3.0.0)
# Requirement already satisfied: future>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from petastorm) (0.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=15.0->petastorm) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->petastorm) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->petastorm) (2018.9)
# Collecting py4j==0.10.9.2
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 56.9 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=b15b9dcb51fbf664aa991165d200546d7a534bf48436c3be342f2335b37c4b8e
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# Installing collected packages: py4j, pyspark, diskcache, petastorm
# Successfully installed diskcache-5.2.1 petastorm-0.11.3 py4j-0.10.9.2 pyspark-3.2.0

# %%
import ludwig
ludwig.__version__
# Out:
# '0.4'

# %% [markdown]
# ### ライブラリーのインポート

# %%
from ludwig.api import LudwigModel

# %% [markdown]
# ### データのダウンロード
# タイタニックの生存予測データをダウンロードします。<br>
# 第1回「AutoMLとは」の「タイタニックの生存予測データの取得方法と解説」の章を参照してください。

# %%
# データの準備
# !wget -N https://github.com/aiq2020-tw/automl-notebooks/raw/main/titanic.zip
# !unzip titanic.zip
# Out:
# A
# --2021-11-23 07:00:48--  https://github.com/aiq2020-tw/automl-notebooks/raw/main/titanic.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/aiq2020-tw/automl-notebooks/main/titanic.zip [following]
# --2021-11-23 07:00:48--  https://raw.githubusercontent.com/aiq2020-tw/automl-notebooks/main/titanic.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34877 (34K) [application/zip]
# Saving to: ‘titanic.zip’
#
# titanic.zip         100%[===================>]  34.06K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-11-23 07:00:48 (126 MB/s) - ‘titanic.zip’ saved [34877/34877]
#
# Archive:  titanic.zip
# replace gender_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
# 学習データとテストデータの確認
import pandas as pd
train_df = pd.read_csv('train.csv')
print('Train data shape:', train_df.shape)
test_df = pd.read_csv('test.csv')
print('Test data shape:', test_df.shape)
# Out:
# Train data shape: (891, 12)
# Test data shape: (418, 11)

# %% [markdown]
# ### データの前処理
# 前処理などの必要な情報は、configとして事前に定義しておきます。<br>
# 入力データ列と出力データ列にも定義しない列は利用されないため、元のテーブルに対して列を削除しておくような前処理は不要です。

# %%
# 辞書型でconfigを記載
config = {
    # データ分割の比率を設定する
    'preprocessing': {'split_probabilities': [0.7, 0.2, 0.1]},
    # 説明変数を設定する
    'input_features': [{'name': 'Pclass', 'type': 'category'},
                       {'name': 'Sex', 'type': 'category'},
                       {'name': 'Age',
                        'preprocessing': {
                            'missing_value_strategy': 'fill_with_mean'},
                        'type': 'numerical'},
                       {'name': 'SibSp', 'type': 'numerical'},
                       {'name': 'Parch', 'type': 'numerical'},
                       {'name': 'Fare',
                        'preprocessing': {
                            'missing_value_strategy': 'fill_with_mean'},
                        'type': 'numerical'},
                       {'name': 'Embarked', 'type': 'category'}],
    # 目的変数を設定する
    'output_features': [{'name': 'Survived', 'type': 'binary'}],
    # 学習に関するパラメーターを設定する（任意）
    'training': {
        'batch_size': 128,
        'epochs': 300,
        'early_stop': 5,
        'learning_rate': 0.001}
    }

# %% [markdown]
# ### モデルの学習

# %%
# Ludwigモデルのインスタンスを生成する
import logging
model = LudwigModel(config, logging_level=logging.INFO)

# %%
# モデルの学習を行う
train_stats = model.train(train_df, random_seed=42)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 459.14it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 391.24it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 425.69it/s]
# Took 0.1289s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6830 │     0.6270 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.6398 │     0.6686 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.6541 │     0.6739 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6830 │
# ├────────────┼────────┤
# │ vali       │ 0.6398 │
# ├────────────┼────────┤
# │ test       │ 0.6541 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  41
# Training: 100%|██████████| 5/5 [00:00<00:00, 165.23it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 430.18it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 245.83it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 338.99it/s]
# Took 0.1363s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6777 │     0.6333 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.6254 │     0.6864 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.6482 │     0.6848 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6777 │
# ├────────────┼────────┤
# │ vali       │ 0.6254 │
# ├────────────┼────────┤
# │ test       │ 0.6482 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  42
# Training: 100%|██████████| 5/5 [00:00<00:00, 192.63it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 342.84it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 213.78it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 526.06it/s]
# Took 0.1371s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6700 │     0.6349 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.6121 │     0.6923 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.6384 │     0.6848 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6700 │
# ├────────────┼────────┤
# │ vali       │ 0.6121 │
# ├────────────┼────────┤
# │ test       │ 0.6384 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  43
# Training: 100%|██████████| 5/5 [00:00<00:00, 170.44it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 331.03it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 356.96it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 386.93it/s]
# Took 0.1519s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6606 │     0.6429 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.6009 │     0.7160 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.6257 │     0.6957 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6606 │
# ├────────────┼────────┤
# │ vali       │ 0.6009 │
# ├────────────┼────────┤
# │ test       │ 0.6257 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  44
# Training: 100%|██████████| 5/5 [00:00<00:00, 228.27it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 314.75it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 328.93it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 340.09it/s]
# Took 0.1292s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6538 │     0.6508 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5940 │     0.7101 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.6160 │     0.6957 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6538 │
# ├────────────┼────────┤
# │ vali       │ 0.5940 │
# ├────────────┼────────┤
# │ test       │ 0.6160 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  45
# Training: 100%|██████████| 5/5 [00:00<00:00, 198.92it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 264.68it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 211.65it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 385.75it/s]
# Took 0.1441s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6488 │     0.6508 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5888 │     0.7219 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.6097 │     0.6957 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6488 │
# ├────────────┼────────┤
# │ vali       │ 0.5888 │
# ├────────────┼────────┤
# │ test       │ 0.6097 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  46
# Training: 100%|██████████| 5/5 [00:00<00:00, 202.33it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 459.38it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 440.32it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 383.39it/s]
# Took 0.1142s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6443 │     0.6524 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5838 │     0.7219 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.6042 │     0.7065 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6443 │
# ├────────────┼────────┤
# │ vali       │ 0.5838 │
# ├────────────┼────────┤
# │ test       │ 0.6042 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  47
# Training: 100%|██████████| 5/5 [00:00<00:00, 177.13it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 318.03it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 487.79it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 526.00it/s]
# Took 0.1391s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6400 │     0.6508 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5786 │     0.7219 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5993 │     0.7065 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6400 │
# ├────────────┼────────┤
# │ vali       │ 0.5786 │
# ├────────────┼────────┤
# │ test       │ 0.5993 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  48
# Training: 100%|██████████| 5/5 [00:00<00:00, 163.22it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 329.40it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 486.80it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 402.95it/s]
# Took 0.1367s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6357 │     0.6524 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5731 │     0.7278 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5950 │     0.7065 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6357 │
# ├────────────┼────────┤
# │ vali       │ 0.5731 │
# ├────────────┼────────┤
# │ test       │ 0.5950 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  49
# Training: 100%|██████████| 5/5 [00:00<00:00, 189.44it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 572.05it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 478.91it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 354.28it/s]
# Took 0.1301s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6316 │     0.6524 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5675 │     0.7396 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5909 │     0.7065 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6316 │
# ├────────────┼────────┤
# │ vali       │ 0.5675 │
# ├────────────┼────────┤
# │ test       │ 0.5909 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  50
# Training: 100%|██████████| 5/5 [00:00<00:00, 206.88it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 335.98it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 420.00it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 380.61it/s]
# Took 0.1130s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6277 │     0.6524 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5624 │     0.7337 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5873 │     0.7174 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6277 │
# ├────────────┼────────┤
# │ vali       │ 0.5624 │
# ├────────────┼────────┤
# │ test       │ 0.5873 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  51
# Training: 100%|██████████| 5/5 [00:00<00:00, 176.32it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 387.62it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 294.96it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 270.98it/s]
# Took 0.1197s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6240 │     0.6556 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5588 │     0.7337 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5835 │     0.7174 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6240 │
# ├────────────┼────────┤
# │ vali       │ 0.5588 │
# ├────────────┼────────┤
# │ test       │ 0.5835 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  52
# Training: 100%|██████████| 5/5 [00:00<00:00, 176.04it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 406.76it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 425.58it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 347.21it/s]
# Took 0.1355s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6204 │     0.6556 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5546 │     0.7396 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5801 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6204 │
# ├────────────┼────────┤
# │ vali       │ 0.5546 │
# ├────────────┼────────┤
# │ test       │ 0.5801 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  53
# Training: 100%|██████████| 5/5 [00:00<00:00, 203.06it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 512.56it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 205.43it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 261.51it/s]
# Took 0.1533s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6169 │     0.6587 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5503 │     0.7456 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5769 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6169 │
# ├────────────┼────────┤
# │ vali       │ 0.5503 │
# ├────────────┼────────┤
# │ test       │ 0.5769 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  54
# Training: 100%|██████████| 5/5 [00:00<00:00, 182.76it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 307.49it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 446.49it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 232.05it/s]
# Took 0.1296s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6134 │     0.6603 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5470 │     0.7456 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5736 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6134 │
# ├────────────┼────────┤
# │ vali       │ 0.5470 │
# ├────────────┼────────┤
# │ test       │ 0.5736 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  55
# Training: 100%|██████████| 5/5 [00:00<00:00, 201.16it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 464.06it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 418.28it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 397.72it/s]
# Took 0.1189s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6099 │     0.6619 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5433 │     0.7456 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5703 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6099 │
# ├────────────┼────────┤
# │ vali       │ 0.5433 │
# ├────────────┼────────┤
# │ test       │ 0.5703 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  56
# Training: 100%|██████████| 5/5 [00:00<00:00, 157.18it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 340.35it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 395.80it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 328.63it/s]
# Took 0.1285s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6066 │     0.6603 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5397 │     0.7456 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5677 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6066 │
# ├────────────┼────────┤
# │ vali       │ 0.5397 │
# ├────────────┼────────┤
# │ test       │ 0.5677 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  57
# Training: 100%|██████████| 5/5 [00:00<00:00, 197.05it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 251.58it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 429.33it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 300.54it/s]
# Took 0.1341s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6033 │     0.6651 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5372 │     0.7456 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5645 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6033 │
# ├────────────┼────────┤
# │ vali       │ 0.5372 │
# ├────────────┼────────┤
# │ test       │ 0.5645 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  58
# Training: 100%|██████████| 5/5 [00:00<00:00, 187.76it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 278.71it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 228.98it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 296.23it/s]
# Took 0.1360s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.6000 │     0.6667 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5349 │     0.7456 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5617 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6000 │
# ├────────────┼────────┤
# │ vali       │ 0.5349 │
# ├────────────┼────────┤
# │ test       │ 0.5617 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  59
# Training: 100%|██████████| 5/5 [00:00<00:00, 210.32it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 398.44it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 432.07it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 338.09it/s]
# Took 0.1382s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5968 │     0.6730 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5310 │     0.7515 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5590 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5968 │
# ├────────────┼────────┤
# │ vali       │ 0.5310 │
# ├────────────┼────────┤
# │ test       │ 0.5590 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  60
# Training: 100%|██████████| 5/5 [00:00<00:00, 191.10it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 499.79it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 299.30it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 333.91it/s]
# Took 0.1227s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5936 │     0.6746 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5281 │     0.7515 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5564 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5936 │
# ├────────────┼────────┤
# │ vali       │ 0.5281 │
# ├────────────┼────────┤
# │ test       │ 0.5564 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  61
# Training: 100%|██████████| 5/5 [00:00<00:00, 149.46it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 497.00it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 410.20it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 162.51it/s]
# Took 0.1432s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5906 │     0.6746 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5263 │     0.7456 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5533 │     0.7174 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5906 │
# ├────────────┼────────┤
# │ vali       │ 0.5263 │
# ├────────────┼────────┤
# │ test       │ 0.5533 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  62
# Training: 100%|██████████| 5/5 [00:00<00:00, 149.70it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 514.50it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 452.63it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 300.95it/s]
# Took 0.1106s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5875 │     0.6778 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5227 │     0.7515 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5505 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5875 │
# ├────────────┼────────┤
# │ vali       │ 0.5227 │
# ├────────────┼────────┤
# │ test       │ 0.5505 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  63
# Training: 100%|██████████| 5/5 [00:00<00:00, 183.99it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 232.81it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 420.82it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 340.56it/s]
# Took 0.1266s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5845 │     0.6825 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5193 │     0.7633 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5480 │     0.7283 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5845 │
# ├────────────┼────────┤
# │ vali       │ 0.5193 │
# ├────────────┼────────┤
# │ test       │ 0.5480 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  64
# Training: 100%|██████████| 5/5 [00:00<00:00, 118.59it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 495.29it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 382.62it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 394.16it/s]
# Took 0.1478s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5815 │     0.6841 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5158 │     0.7633 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5453 │     0.7391 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5815 │
# ├────────────┼────────┤
# │ vali       │ 0.5158 │
# ├────────────┼────────┤
# │ test       │ 0.5453 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  65
# Training: 100%|██████████| 5/5 [00:00<00:00, 211.31it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 431.79it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 514.23it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 364.34it/s]
# Took 0.1246s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5786 │     0.6857 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5127 │     0.7633 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5428 │     0.7609 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5786 │
# ├────────────┼────────┤
# │ vali       │ 0.5127 │
# ├────────────┼────────┤
# │ test       │ 0.5428 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  66
# Training: 100%|██████████| 5/5 [00:00<00:00, 135.44it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 496.13it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 284.53it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 316.26it/s]
# Took 0.1482s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5758 │     0.6889 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5101 │     0.7633 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5400 │     0.7500 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5758 │
# ├────────────┼────────┤
# │ vali       │ 0.5101 │
# ├────────────┼────────┤
# │ test       │ 0.5400 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  67
# Training: 100%|██████████| 5/5 [00:00<00:00, 183.92it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 413.23it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 478.39it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 390.42it/s]
# Took 0.1051s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5729 │     0.6905 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5071 │     0.7692 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5375 │     0.7609 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5729 │
# ├────────────┼────────┤
# │ vali       │ 0.5071 │
# ├────────────┼────────┤
# │ test       │ 0.5375 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  68
# Training: 100%|██████████| 5/5 [00:00<00:00, 171.48it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 410.29it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 422.09it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 276.34it/s]
# Took 0.1513s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5702 │     0.6905 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5041 │     0.7692 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5354 │     0.7609 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5702 │
# ├────────────┼────────┤
# │ vali       │ 0.5041 │
# ├────────────┼────────┤
# │ test       │ 0.5354 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  69
# Training: 100%|██████████| 5/5 [00:00<00:00, 164.67it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 289.93it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 509.67it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 401.87it/s]
# Took 0.1440s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5675 │     0.6952 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.5013 │     0.7692 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5328 │     0.7609 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5675 │
# ├────────────┼────────┤
# │ vali       │ 0.5013 │
# ├────────────┼────────┤
# │ test       │ 0.5328 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  70
# Training: 100%|██████████| 5/5 [00:00<00:00, 197.86it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 360.35it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 414.35it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 349.32it/s]
# Took 0.1426s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5647 │     0.7048 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4991 │     0.7692 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5303 │     0.7609 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5647 │
# ├────────────┼────────┤
# │ vali       │ 0.4991 │
# ├────────────┼────────┤
# │ test       │ 0.5303 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  71
# Training: 100%|██████████| 5/5 [00:00<00:00, 177.10it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 411.18it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 196.01it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 304.09it/s]
# Took 0.1473s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5622 │     0.7111 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4970 │     0.7751 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5280 │     0.7609 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5622 │
# ├────────────┼────────┤
# │ vali       │ 0.4970 │
# ├────────────┼────────┤
# │ test       │ 0.5280 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  72
# Training: 100%|██████████| 5/5 [00:00<00:00, 170.64it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 339.21it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 394.15it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 391.77it/s]
# Took 0.1384s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5596 │     0.7159 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4944 │     0.7751 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5258 │     0.7609 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5596 │
# ├────────────┼────────┤
# │ vali       │ 0.4944 │
# ├────────────┼────────┤
# │ test       │ 0.5258 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  73
# Training: 100%|██████████| 5/5 [00:00<00:00, 187.72it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 526.08it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 478.94it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 386.07it/s]
# Took 0.1123s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5571 │     0.7127 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4914 │     0.7811 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5238 │     0.7717 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5571 │
# ├────────────┼────────┤
# │ vali       │ 0.4914 │
# ├────────────┼────────┤
# │ test       │ 0.5238 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  74
# Training: 100%|██████████| 5/5 [00:00<00:00, 170.47it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 499.81it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 452.85it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 286.89it/s]
# Took 0.1344s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5546 │     0.7111 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4891 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5213 │     0.7826 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5546 │
# ├────────────┼────────┤
# │ vali       │ 0.4891 │
# ├────────────┼────────┤
# │ test       │ 0.5213 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  75
# Training: 100%|██████████| 5/5 [00:00<00:00, 186.95it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 455.18it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 441.62it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 362.23it/s]
# Took 0.1291s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5523 │     0.7143 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4868 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5197 │     0.7826 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5523 │
# ├────────────┼────────┤
# │ vali       │ 0.4868 │
# ├────────────┼────────┤
# │ test       │ 0.5197 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  76
# Training: 100%|██████████| 5/5 [00:00<00:00, 182.49it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 519.59it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 448.35it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 389.62it/s]
# Took 0.1244s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5499 │     0.7143 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4848 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5176 │     0.7935 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5499 │
# ├────────────┼────────┤
# │ vali       │ 0.4848 │
# ├────────────┼────────┤
# │ test       │ 0.5176 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  77
# Training: 100%|██████████| 5/5 [00:00<00:00, 147.83it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 508.17it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 472.20it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 391.77it/s]
# Took 0.1373s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5475 │     0.7143 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4823 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5156 │     0.7935 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5475 │
# ├────────────┼────────┤
# │ vali       │ 0.4823 │
# ├────────────┼────────┤
# │ test       │ 0.5156 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  78
# Training: 100%|██████████| 5/5 [00:00<00:00, 184.19it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 499.89it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 469.63it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 375.09it/s]
# Took 0.1275s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5452 │     0.7222 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4795 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5133 │     0.7935 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5452 │
# ├────────────┼────────┤
# │ vali       │ 0.4795 │
# ├────────────┼────────┤
# │ test       │ 0.5133 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  79
# Training: 100%|██████████| 5/5 [00:00<00:00, 163.06it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 278.53it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 470.87it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 370.36it/s]
# Took 0.1609s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5430 │     0.7317 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4768 │     0.7929 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5109 │     0.7935 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5430 │
# ├────────────┼────────┤
# │ vali       │ 0.4768 │
# ├────────────┼────────┤
# │ test       │ 0.5109 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  80
# Training: 100%|██████████| 5/5 [00:00<00:00, 177.38it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 258.75it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 207.71it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 350.75it/s]
# Took 0.1446s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5408 │     0.7317 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4746 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5092 │     0.7935 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5408 │
# ├────────────┼────────┤
# │ vali       │ 0.4746 │
# ├────────────┼────────┤
# │ test       │ 0.5092 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  81
# Training: 100%|██████████| 5/5 [00:00<00:00, 158.18it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 261.11it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 449.33it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 274.44it/s]
# Took 0.1396s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5387 │     0.7302 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4726 │     0.7929 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5073 │     0.7935 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5387 │
# ├────────────┼────────┤
# │ vali       │ 0.4726 │
# ├────────────┼────────┤
# │ test       │ 0.5073 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  82
# Training: 100%|██████████| 5/5 [00:00<00:00, 210.15it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 361.73it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 446.92it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 346.46it/s]
# Took 0.1167s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5366 │     0.7365 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4709 │     0.7988 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5058 │     0.7935 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5366 │
# ├────────────┼────────┤
# │ vali       │ 0.4709 │
# ├────────────┼────────┤
# │ test       │ 0.5058 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  83
# Training: 100%|██████████| 5/5 [00:00<00:00, 137.57it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 297.92it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 461.67it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 205.57it/s]
# Took 0.1406s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5346 │     0.7381 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4686 │     0.7988 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5040 │     0.8043 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5346 │
# ├────────────┼────────┤
# │ vali       │ 0.4686 │
# ├────────────┼────────┤
# │ test       │ 0.5040 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  84
# Training: 100%|██████████| 5/5 [00:00<00:00, 165.11it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 250.36it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 480.89it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 383.22it/s]
# Took 0.1347s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5326 │     0.7365 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4663 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5027 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5326 │
# ├────────────┼────────┤
# │ vali       │ 0.4663 │
# ├────────────┼────────┤
# │ test       │ 0.5027 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  85
# Training: 100%|██████████| 5/5 [00:00<00:00, 181.98it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 363.88it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 289.62it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 371.44it/s]
# Took 0.1406s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5307 │     0.7397 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4643 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.5009 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5307 │
# ├────────────┼────────┤
# │ vali       │ 0.4643 │
# ├────────────┼────────┤
# │ test       │ 0.5009 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  86
# Training: 100%|██████████| 5/5 [00:00<00:00, 144.50it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 375.66it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 364.75it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 372.66it/s]
# Took 0.1348s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5287 │     0.7413 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4627 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4991 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5287 │
# ├────────────┼────────┤
# │ vali       │ 0.4627 │
# ├────────────┼────────┤
# │ test       │ 0.4991 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  87
# Training: 100%|██████████| 5/5 [00:00<00:00, 161.75it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 260.23it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 462.82it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 333.97it/s]
# Took 0.1394s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5269 │     0.7460 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4608 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4974 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5269 │
# ├────────────┼────────┤
# │ vali       │ 0.4608 │
# ├────────────┼────────┤
# │ test       │ 0.4974 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  88
# Training: 100%|██████████| 5/5 [00:00<00:00, 171.06it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 341.13it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 414.23it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 395.65it/s]
# Took 0.1145s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5251 │     0.7508 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4595 │     0.7988 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4957 │     0.8043 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5251 │
# ├────────────┼────────┤
# │ vali       │ 0.4595 │
# ├────────────┼────────┤
# │ test       │ 0.4957 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  89
# Training: 100%|██████████| 5/5 [00:00<00:00, 196.13it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 478.64it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 421.77it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 243.66it/s]
# Took 0.1408s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5234 │     0.7540 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4579 │     0.7988 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4946 │     0.8261 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5234 │
# ├────────────┼────────┤
# │ vali       │ 0.4579 │
# ├────────────┼────────┤
# │ test       │ 0.4946 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  90
# Training: 100%|██████████| 5/5 [00:00<00:00, 169.26it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 273.19it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 462.31it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 380.16it/s]
# Took 0.1418s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5216 │     0.7540 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4559 │     0.7929 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4932 │     0.8261 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5216 │
# ├────────────┼────────┤
# │ vali       │ 0.4559 │
# ├────────────┼────────┤
# │ test       │ 0.4932 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  91
# Training: 100%|██████████| 5/5 [00:00<00:00, 183.93it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 543.26it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 390.13it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 408.01it/s]
# Took 0.1312s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5200 │     0.7571 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4540 │     0.7929 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4915 │     0.8261 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5200 │
# ├────────────┼────────┤
# │ vali       │ 0.4540 │
# ├────────────┼────────┤
# │ test       │ 0.4915 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  92
# Training: 100%|██████████| 5/5 [00:00<00:00, 191.57it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 543.56it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 525.40it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 398.93it/s]
# Took 0.1304s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5184 │     0.7556 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4520 │     0.7929 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4904 │     0.8261 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5184 │
# ├────────────┼────────┤
# │ vali       │ 0.4520 │
# ├────────────┼────────┤
# │ test       │ 0.4904 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  93
# Training: 100%|██████████| 5/5 [00:00<00:00, 185.98it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 404.18it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 230.75it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 355.57it/s]
# Took 0.1325s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5169 │     0.7524 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4505 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4891 │     0.8261 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5169 │
# ├────────────┼────────┤
# │ vali       │ 0.4505 │
# ├────────────┼────────┤
# │ test       │ 0.4891 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  94
# Training: 100%|██████████| 5/5 [00:00<00:00, 140.60it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 422.06it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 442.06it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 333.97it/s]
# Took 0.1406s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.5153 │     0.7556 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4495 │     0.7870 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4877 │     0.8261 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.5153 │
# ├────────────┼────────┤
# ...
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4588 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4009 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4354 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4588 │
# ├────────────┼────────┤
# │ vali       │ 0.4009 │
# ├────────────┼────────┤
# │ test       │ 0.4354 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 208
# Training: 100%|██████████| 5/5 [00:00<00:00, 179.14it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 475.22it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 453.56it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 383.04it/s]
# Took 0.1109s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4587 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4009 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4353 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4587 │
# ├────────────┼────────┤
# │ vali       │ 0.4009 │
# ├────────────┼────────┤
# │ test       │ 0.4353 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 209
# Training: 100%|██████████| 5/5 [00:00<00:00, 157.12it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 245.81it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 387.46it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 166.16it/s]
# Took 0.1442s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4585 │     0.7952 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4006 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4346 │     0.8043 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4585 │
# ├────────────┼────────┤
# │ vali       │ 0.4006 │
# ├────────────┼────────┤
# │ test       │ 0.4346 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 210
# Training: 100%|██████████| 5/5 [00:00<00:00, 211.81it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 527.52it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 440.69it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 376.54it/s]
# Took 0.1278s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4584 │     0.7984 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4008 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4348 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4584 │
# ├────────────┼────────┤
# │ vali       │ 0.4008 │
# ├────────────┼────────┤
# │ test       │ 0.4348 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch 211
# Training: 100%|██████████| 5/5 [00:00<00:00, 195.01it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 449.93it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 475.03it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 78.53it/s]
# Took 0.1367s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4583 │     0.7984 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4014 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4352 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4583 │
# ├────────────┼────────┤
# │ vali       │ 0.4014 │
# ├────────────┼────────┤
# │ test       │ 0.4352 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch 212
# Training: 100%|██████████| 5/5 [00:00<00:00, 182.23it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 485.28it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 423.05it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 250.66it/s]
# Took 0.1388s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4580 │     0.7984 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4010 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4347 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4580 │
# ├────────────┼────────┤
# │ vali       │ 0.4010 │
# ├────────────┼────────┤
# │ test       │ 0.4347 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 3 epochs ago
#
#
# Epoch 213
# Training: 100%|██████████| 5/5 [00:00<00:00, 193.18it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 512.08it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 464.33it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 386.04it/s]
# Took 0.1257s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4578 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4006 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4342 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4578 │
# ├────────────┼────────┤
# │ vali       │ 0.4006 │
# ├────────────┼────────┤
# │ test       │ 0.4342 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 4 epochs ago
#
#
# Epoch 214
# Training: 100%|██████████| 5/5 [00:00<00:00, 145.63it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 345.50it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 322.13it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 83.60it/s]
# Took 0.1440s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4577 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4003 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4336 │     0.8043 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4577 │
# ├────────────┼────────┤
# │ vali       │ 0.4003 │
# ├────────────┼────────┤
# │ test       │ 0.4336 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 215
# Training: 100%|██████████| 5/5 [00:00<00:00, 161.88it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 332.22it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 446.32it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 283.40it/s]
# Took 0.1298s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4575 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4004 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4337 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4575 │
# ├────────────┼────────┤
# │ vali       │ 0.4004 │
# ├────────────┼────────┤
# │ test       │ 0.4337 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch 216
# Training: 100%|██████████| 5/5 [00:00<00:00, 118.66it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 367.10it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 495.90it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 49.24it/s]
# Took 0.1761s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4573 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4005 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4337 │     0.8043 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4573 │
# ├────────────┼────────┤
# │ vali       │ 0.4005 │
# ├────────────┼────────┤
# │ test       │ 0.4337 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch 217
# Training: 100%|██████████| 5/5 [00:00<00:00, 182.86it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 263.88it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 328.62it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 356.33it/s]
# Took 0.1302s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4571 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4005 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4335 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4571 │
# ├────────────┼────────┤
# │ vali       │ 0.4005 │
# ├────────────┼────────┤
# │ test       │ 0.4335 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 3 epochs ago
#
#
# Epoch 218
# Training: 100%|██████████| 5/5 [00:00<00:00, 189.57it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 474.80it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 474.95it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 355.03it/s]
# Took 0.1243s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4570 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4001 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4329 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4570 │
# ├────────────┼────────┤
# │ vali       │ 0.4001 │
# ├────────────┼────────┤
# │ test       │ 0.4329 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 219
# Training: 100%|██████████| 5/5 [00:00<00:00, 195.77it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 534.01it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 445.94it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 367.08it/s]
# Took 0.1272s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4568 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.3998 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4322 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4568 │
# ├────────────┼────────┤
# │ vali       │ 0.3998 │
# ├────────────┼────────┤
# │ test       │ 0.4322 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 220
# Training: 100%|██████████| 5/5 [00:00<00:00, 197.55it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 507.33it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 447.03it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 89.48it/s]
# Took 0.1428s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4567 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4000 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4324 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4567 │
# ├────────────┼────────┤
# │ vali       │ 0.4000 │
# ├────────────┼────────┤
# │ test       │ 0.4324 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch 221
# Training: 100%|██████████| 5/5 [00:00<00:00, 187.30it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 523.46it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 240.60it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 351.64it/s]
# Took 0.1358s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4565 │     0.7984 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.3999 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4321 │     0.8043 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4565 │
# ├────────────┼────────┤
# │ vali       │ 0.3999 │
# ├────────────┼────────┤
# │ test       │ 0.4321 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch 222
# Training: 100%|██████████| 5/5 [00:00<00:00, 164.41it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 531.66it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 447.13it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 357.85it/s]
# Took 0.1365s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4564 │     0.7984 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4001 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4322 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4564 │
# ├────────────┼────────┤
# │ vali       │ 0.4001 │
# ├────────────┼────────┤
# │ test       │ 0.4322 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 3 epochs ago
#
#
# Epoch 223
# Training: 100%|██████████| 5/5 [00:00<00:00, 190.46it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 484.12it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 418.89it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 198.29it/s]
# Took 0.1217s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4562 │     0.7984 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.3998 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4317 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4562 │
# ├────────────┼────────┤
# │ vali       │ 0.3998 │
# ├────────────┼────────┤
# │ test       │ 0.4317 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 4 epochs ago
#
#
# Epoch 224
# Training: 100%|██████████| 5/5 [00:00<00:00, 180.71it/s]
# Evaluation train: 100%|██████████| 5/5 [00:00<00:00, 466.55it/s]
# Evaluation vali : 100%|██████████| 2/2 [00:00<00:00, 480.31it/s]
# Evaluation test : 100%|██████████| 1/1 [00:00<00:00, 139.83it/s]
# Took 0.1206s
# ╒════════════╤════════╤════════════╕
# │ Survived   │   loss │   accuracy │
# ╞════════════╪════════╪════════════╡
# │ train      │ 0.4561 │     0.7968 │
# ├────────────┼────────┼────────────┤
# │ vali       │ 0.4000 │     0.8166 │
# ├────────────┼────────┼────────────┤
# │ test       │ 0.4316 │     0.8152 │
# ╘════════════╧════════╧════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.4561 │
# ├────────────┼────────┤
# │ vali       │ 0.4000 │
# ├────────────┼────────┤
# │ test       │ 0.4316 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 5 epochs ago
#
# EARLY STOPPING due to lack of validation improvement, it has been 5 epochs since last validation improvement
#
# Best validation model epoch: 219
# Best validation model loss on validation set combined: 0.3997703194618225
# Best validation model loss on test set combined: 0.4322311580181122
#
# Finished: api_experiment_run
# Saved to: results/api_experiment_run

# %% [markdown]
# ### テストデータの予測
# 学習したモデルを用いてテストデータの予測を行います。<br>
# 分類の予測結果（Survived_predictions）だけでなく、その確率（Survived_probability）も併せて出力されます。

# %%
# 予測
predictions = model.predict(test_df)
predictions[0]
# Out:
# Prediction: 100%|██████████| 4/4 [00:00<00:00, 13.17it/s]
#                         Survived_probabilities  ...  Survived_probability
# 0    [0.8923938572406769, 0.10760614275932312]  ...              0.892394
# 1       [0.509885311126709, 0.490114688873291]  ...              0.509885
# 2     [0.8041219711303711, 0.1958780288696289]  ...              0.804122
# 3     [0.8927166759967804, 0.1072833240032196]  ...              0.892717
# 4     [0.4722605347633362, 0.5277394652366638]  ...              0.527739
# ..                                         ...  ...                   ...
# 413   [0.8951968252658844, 0.1048031747341156]  ...              0.895197
# 414   [0.05979800224304199, 0.940201997756958]  ...              0.940202
# 415  [0.9023429751396179, 0.09765702486038208]  ...              0.902343
# 416   [0.8951968252658844, 0.1048031747341156]  ...              0.895197
# 417   [0.868681013584137, 0.13131898641586304]  ...              0.868681
#
# [418 rows x 5 columns]

# %%
# Kaggle投稿用のファイルを作成する
output = pd.DataFrame({'PassengerID': test_df.PassengerId,
                       'Survived':
                       predictions[0]['Survived_predictions'].astype('int32')})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ## その他の機能と応用

# %% [markdown]
# ### ハイパーパラメーターチューニング
# ludwigのサブパッケージである「hyperopt」を用いてハイパーパラメーターチューニングを行います。<br>
# インストール後、必要に応じてランタイムの再起動を実行してください。

# %%
# ハイパーパラメーターチューニング用のライブラリを別にインストール
# !pip install ludwig[hyperopt]

# scikit-learnのアップグレード
# !pip install --upgrade scikit-learn==0.22.2.post1
# Out:
# Requirement already satisfied: ludwig[hyperopt] in /usr/local/lib/python3.7/dist-packages (0.4)
# Requirement already satisfied: pandas<1.1.5,>=0.25 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (1.1.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (4.62.3)
# Requirement already satisfied: tensorflow-addons>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (0.15.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (1.0.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (0.5.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (3.4.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (1.19.5)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (3.13)
# Requirement already satisfied: Cython>=0.25 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (0.29.24)
# Requirement already satisfied: h5py!=3.0.0,>=2.6 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (3.1.0)
# Requirement already satisfied: tabulate>=0.7 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (0.8.9)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (3.0.0)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (1.4.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (2.5.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (2.23.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (2.6.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (1.5.12)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (1.1.0)
# Requirement already satisfied: tensorflow>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (2.7.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (0.12.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (4.2.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (2021.11.0)
# Requirement already satisfied: xlwt in /usr/local/lib/python3.7/dist-packages (from ludwig[hyperopt]) (1.3.0)
# Collecting fiber
#   Downloading fiber-0.2.1.tar.gz (61 kB)
#      |████████████████████████████████| 61 kB 191 kB/s
# Collecting ray[tune]
#   Downloading ray-1.8.0-cp37-cp37m-manylinux2014_x86_64.whl (54.7 MB)
#      |████████████████████████████████| 54.7 MB 1.3 MB/s
# Collecting bayesmark>=0.0.7
#   Downloading bayesmark-0.0.8.tar.gz (86 kB)
#      |████████████████████████████████| 86 kB 5.0 MB/s
# Collecting pySOT
#   Downloading pySOT-0.3.3-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.2 MB/s
# Collecting pathvalidate>=0.29.0
#   Downloading pathvalidate-2.5.0-py3-none-any.whl (19 kB)
# Collecting GitPython>=2.1.11
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 54.3 MB/s
# Requirement already satisfied: importlib-metadata>=0.18 in /usr/local/lib/python3.7/dist-packages (from bayesmark>=0.0.7->ludwig[hyperopt]) (4.8.2)
# Requirement already satisfied: xarray>=0.12.2 in /usr/local/lib/python3.7/dist-packages (from bayesmark>=0.0.7->ludwig[hyperopt]) (0.18.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=2.1.11->bayesmark>=0.0.7->ludwig[hyperopt]) (3.10.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py!=3.0.0,>=2.6->ludwig[hyperopt]) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.18->bayesmark>=0.0.7->ludwig[hyperopt]) (3.6.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<1.1.5,>=0.25->ludwig[hyperopt]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.1.5,>=0.25->ludwig[hyperopt]) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<1.1.5,>=0.25->ludwig[hyperopt]) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->ludwig[hyperopt]) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->ludwig[hyperopt]) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (0.22.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (3.3.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (1.6.3)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (12.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (1.13.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (3.17.3)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (0.37.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.1->ludwig[hyperopt]) (1.42.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig[hyperopt]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig[hyperopt]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig[hyperopt]) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ludwig[hyperopt]) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.3.1->ludwig[hyperopt]) (3.1.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons>=0.13.0->ludwig[hyperopt]) (2.7.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->ludwig[hyperopt]) (1.5.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->ludwig[hyperopt]) (3.14.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->ludwig[hyperopt]) (0.7.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->ludwig[hyperopt]) (0.4.3)
# Collecting nnpy-bundle
#   Downloading nnpy_bundle-1.4.2.post1-cp37-cp37m-manylinux1_x86_64.whl (165 kB)
#      |████████████████████████████████| 165 kB 20.2 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from fiber->ludwig[hyperopt]) (5.4.8)
# Collecting docker
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 52.7 MB/s
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from fiber->ludwig[hyperopt]) (1.3.0)
# Collecting kubernetes
#   Downloading kubernetes-19.15.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 54.7 MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from fiber->ludwig[hyperopt]) (7.1.2)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->ludwig[hyperopt]) (5.0.2)
# Collecting PyYAML>=3.12
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 53.5 MB/s
# Requirement already satisfied: cffi in /usr/local/lib/python3.7/dist-packages (from nnpy-bundle->fiber->ludwig[hyperopt]) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi->nnpy-bundle->fiber->ludwig[hyperopt]) (2.21)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl->ludwig[hyperopt]) (1.4.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl->ludwig[hyperopt]) (1.1.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from pySOT->ludwig[hyperopt]) (0.3.4)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from pySOT->ludwig[hyperopt]) (3.6.4)
# Collecting pyDOE2
#   Downloading pyDOE2-1.3.0.tar.gz (19 kB)
# Collecting POAP>=0.1.25
#   Downloading POAP-0.1.26-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pySOT->ludwig[hyperopt]) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pySOT->ludwig[hyperopt]) (21.2.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pySOT->ludwig[hyperopt]) (8.11.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->pySOT->ludwig[hyperopt]) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pySOT->ludwig[hyperopt]) (1.11.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->ludwig[hyperopt]) (1.3)
# Collecting redis>=3.5.0
#   Downloading redis-4.0.2-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 52.8 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]->ludwig[hyperopt]) (1.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[tune]->ludwig[hyperopt]) (3.4.0)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.4.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 58.0 MB/s
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.7/dist-packages (from tables->ludwig[hyperopt]) (2.7.3)
# Building wheels for collected packages: bayesmark, fiber, pyDOE2
#   Building wheel for bayesmark (setup.py) ... done
#   Created wheel for bayesmark: filename=bayesmark-0.0.8-py3-none-any.whl size=104281 sha256=8f6762f580ee703ac2b0dd1e860ac43d1a03d9659dd920966fa8d93262b6c98e
#   Stored in directory: /root/.cache/pip/wheels/2f/ce/4c/a5b1d0c4df6a56f23176d0100727f91d353e625bbd024ebe7e
#   Building wheel for fiber (setup.py) ... done
#   Created wheel for fiber: filename=fiber-0.2.1-py3-none-any.whl size=77434 sha256=094399581653302bf0c02c6eeadbba9c618529b248171aea0ce3185e8b3bba14
#   Stored in directory: /root/.cache/pip/wheels/ba/75/70/71cc5eeb5783a0fc2ae2defcff301f7d9a57d372d891b1f0f3
#   Building wheel for pyDOE2 (setup.py) ... done
#   Created wheel for pyDOE2: filename=pyDOE2-1.3.0-py3-none-any.whl size=25539 sha256=ac3d98048d52658361689ab9738111ec6e51c893994e96d7949368f9e7279e48
#   Stored in directory: /root/.cache/pip/wheels/49/91/2d/d08e80806bf7756193541f6c03c0492af288fcd6158d3d0998
# Successfully built bayesmark fiber pyDOE2
# Installing collected packages: smmap, deprecated, websocket-client, redis, PyYAML, gitdb, tensorboardX, ray, pyDOE2, POAP, pathvalidate, nnpy-bundle, kubernetes, GitPython, docker, pySOT, fiber, bayesmark
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed GitPython-3.1.24 POAP-0.1.26 PyYAML-6.0 bayesmark-0.0.8 deprecated-1.2.13 docker-5.0.3 fiber-0.2.1 gitdb-4.0.9 kubernetes-19.15.0 nnpy-bundle-1.4.2.post1 pathvalidate-2.5.0 pyDOE2-1.3.0 pySOT-0.3.3 ray-1.8.0 redis-4.0.2 smmap-5.0.0 tensorboardX-2.4.1 websocket-client-1.2.1
# Collecting scikit-learn==0.22.2.post1
#   Downloading scikit_learn-0.22.2.post1-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 32.5 MB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2.post1) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2.post1) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2.post1) (1.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.1
#     Uninstalling scikit-learn-1.0.1:
#       Successfully uninstalled scikit-learn-1.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.22.2.post1 which is incompatible.
# Successfully installed scikit-learn-0.22.2.post1

# %%
# ハイパーパラメーターチューニングの探索範囲を定義
hyperopt_configs = {
    'parameters': {
        'training.learning_rate': {
            'type': 'float',
            'low': 0.0001,
            'high': 0.01,
            'space': 'log',
            'steps': 3,
            },
        'training.batch_size': {
            'type': 'int',
            'low': 32,
            'high': 256,
            'space': 'log',
            'steps': 5,
            'base': 2
            }
        },
    'output_feature': 'Survived',
    'metrics': 'loss',
    'goal': 'minimize',
    'sampler': {
        'type': 'random',
        'num_samples': 10
        },
    'executor': {
        'type': 'parallel',
        'num_workers': 4
        }
    }

# configに対して上記の設定を追加
config['hyperopt'] = hyperopt_configs

# %%
# ハイパーパラメーターチューニングの実行
from ludwig.hyperopt.run import hyperopt
random_parallel_results = hyperopt(
    config,
    dataset=train_df,
    output_directory='results_random_parallel'
)
# Out:
# {   'executor': {   'TF_REQUIRED_MEMORY_PER_WORKER': 100,
#                     'epsilon': 0.01,
#                     'epsilon_memory': 100,
#                     'num_workers': 4,
#                     'type': 'parallel'},
#     'goal': 'minimize',
#     'metric': 'loss',
#     'metrics': 'loss',
#     'output_feature': 'Survived',
#     'parameters': {   'training.batch_size': {   'base': 2,
#                                                  'high': 256,
#                                                  'low': 32,
#                                                  'space': 'log',
#                                                  'steps': 5,
#                                                  'type': 'int'},
#                       'training.learning_rate': {   'high': 0.01,
#                                                     'low': 0.0001,
#                                                     'space': 'log',
#                                                     'steps': 3,
#                                                     'type': 'float'}},
#     'sampler': {'num_samples': 10, 'type': 'random'},
#     'split': 'validation'}
#
#
#
# ╒══════════════════╕
# │ HYPEROPT RESULTS │
# ╘══════════════════╛
#
# score: 0.416985 | parameters: {'training.batch_size': 39, 'training.learning_rate': 0.0020453502780068415}
# score: 0.418628 | parameters: {'training.batch_size': 146, 'training.learning_rate': 0.0003408063211511481}
# score: 0.440201 | parameters: {'training.batch_size': 223, 'training.learning_rate': 0.005788050952745558}
# score: 0.446747 | parameters: {'training.batch_size': 123, 'training.learning_rate': 0.00029509839745428816}
# score: 0.460359 | parameters: {'training.batch_size': 200, 'training.learning_rate': 0.0011689379115000867}
# score: 0.476674 | parameters: {'training.batch_size': 83, 'training.learning_rate': 0.00010869684261670043}
# score: 0.488161 | parameters: {'training.batch_size': 65, 'training.learning_rate': 0.0001518119849068444}
# score: 0.490346 | parameters: {'training.batch_size': 62, 'training.learning_rate': 0.0001429341322733243}
# score: 0.510614 | parameters: {'training.batch_size': 137, 'training.learning_rate': 0.00022161667288523928}
# score: 0.538973 | parameters: {'training.batch_size': 113, 'training.learning_rate': 0.00016807475116496561}
#
# Hyperopt stats saved to: results_random_parallel
# Finished hyperopt

# %% [markdown]
# ハイパーパラメーターチューニングの結果、予測精度の高いパラメーターを発見できました。

# %% [markdown]
# 以上で、タイタニックの生存予測データを使ったLudwigの紹介は終わりです。
